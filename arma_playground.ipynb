# %%
# %matplotlib inline
import statsmodels
import statsmodels.tsa as tsa
import matplotlib.pylab as plt
import preproc
import numpy as np

# %%
import cPickle as pickle
with open('testcube.pickle', 'rb') as f:
    cube = pickle.load(f)

# %%
f = cube['f']['frequency_change']
#f = np.reshape(f, [1,len(f)])
print f.shape
# Out:
# (10, 250)

# %%
plt.plot(f[0])

# %%
p = preproc.local_linear_regression(f)
print f.shape
plt.plot(f[0])
plt.plot(p[0])
# Out:
# (10, 250)
